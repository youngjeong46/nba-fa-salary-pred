# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.basketball-reference.com/leagues/NBA_2009_per_game.html'
if requests.get(url).status_code == 200:
    print("yay")
# Out:
# yay

# %%
page = requests.get(url).text
data_soup = BeautifulSoup(page,"html.parser")

# %%
print(data_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/bbr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
#    <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201903191" rel="dns-prefetch"/>
#    <!-- no:cookie fast load the css.           -->
#    <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect"/>
#    <link crossorigin="" href="https://d2cwpp38twqe55.cloudfront.net" rel="preconnect"/>
#    <style>
# ...

# %% [markdown]
# Get the table with player stats

# %%
player_data=data_soup.find(class_='sortable stats_table');

# %% [markdown]
# Extract all rows of HTML data

# %%
players = [row for row in player_data.find_all('tr')]

# %%
print(players[0].prettify())
# Out:
# <tr>
#  <th aria-label="Rank" class="ranker poptip sort_default_asc show_partial_when_sorting center" data-stat="ranker" data-tip="Rank" scope="col">
#   Rk
#  </th>
#  <th aria-label="Player" class="poptip sort_default_asc center" data-stat="player" scope="col">
#   Player
#  </th>
#  <th aria-label="Position" class="poptip sort_default_asc center" data-stat="pos" data-tip="Position" scope="col">
#   Pos
#  </th>
#  <th aria-label="Age of Player at the start of February 1st of that season." class="poptip sort_default_asc center" data-stat="age" data-tip="Age of Player at the start of February 1st of that season." scope="col">
#   Age
#  </th>
#  <th aria-label="Team" class="poptip sort_default_asc center" data-stat="team_id" data-tip="Team" scope="col">
#   Tm
#  </th>
#  <th aria-label="Games" class="poptip center" data-stat="g" data-tip="Games" scope="col">
#   G
#  </th>
#  <th aria-label="Games Started" class="poptip center" data-stat="gs" data-tip="Games Started" scope="col">
# ...

# %% [markdown]
# Assign header and stick it in as our dataframe columns label

# %%
headers = players[0].find_all('th')
columns = [i.text for i in headers[1:]]

# %%
df_2009 = pd.DataFrame(columns=columns)

# %%
columns
# Out:
# ['Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  '2P',
#  '2PA',
#  '2P%',
#  'eFG%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']

# %% [markdown]
# Insert all entries as dataframe rows

# %%
for entry in players[1:]:
    temp = entry.find_all('td')
    temp = [stat.text for stat in temp]
    if len(temp) == len(columns):
        df_2009.loc[len(df_2009)] = temp

# %%
df_2009.head(10)
# Out:
#               Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...    FT%  \
# 0         Alex Acker  SG  26  TOT  25   0   8.0  1.2   3.0  .395  ...   .500
# 1         Alex Acker  SG  26  DET   7   0   2.9  0.6   1.6  .364  ...   .500
# 2         Alex Acker  SG  26  LAC  18   0   9.9  1.4   3.6  .400  ...   .500
# 3       Hassan Adams  SG  24  TOR  12   0   4.3  0.3   1.1  .308  ...   .500
# 4      Arron Afflalo  SG  23  DET  74   8  16.7  1.8   4.1  .437  ...   .817
# 5       Maurice Ager  SG  24  NJN  20   0   4.9  0.8   2.2  .349  ...   .500
# 6       Blake Ahearn  PG  24  SAS   3   0   6.3  0.7   2.0  .333  ...  1.000
# 7      Alexis Ajinca  PF  20  CHA  31   4   5.9  0.8   2.2  .362  ...   .714
# 8  LaMarcus Aldridge  PF  23  POR  81  81  37.1  7.4  15.3  .484  ...   .781
# 9      Joe Alexander  SF  22  MIL  59   0  12.1  1.7   4.2  .416  ...   .699
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.3  0.6  1.0  0.5  0.2  0.2  0.3  0.4   2.9
# ...
